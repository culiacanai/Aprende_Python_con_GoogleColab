# %% [markdown]
# <a href="https://colab.research.google.com/github/culiacanai/Aprende_Python_con_GoogleColab/blob/main/notebooks/15_Proximos_Pasos.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # 🎓 Próximos Pasos
#
# ### Aprende Python con Google Colab — por [Culiacan.AI](https://culiacan.ai)
#
# **Nivel:** Todos
# **Duración estimada:** 30 minutos
#
# ---
#
# ## 🎉 ¡Felicidades!
#
# Si llegaste hasta aquí, completaste **15 notebooks** que te llevaron desde cero hasta construir un proyecto de Inteligencia Artificial con datos reales. Eso no es poca cosa.
#
# Repasemos lo que aprendiste y hacia dónde puedes seguir creciendo.

# %% [markdown]
# ---
#
# ## 1. Lo que aprendiste
#
# ### Bloque 1: Fundamentos de Python (Notebooks 01–05)
#
# | # | Tema | Habilidad adquirida |
# |---|------|-------------------|
# | 01 | Hola Mundo | Variables, tipos de datos, print, input |
# | 02 | Condicionales y Ciclos | if/elif/else, for, while, lógica de control |
# | 03 | Funciones | Definir funciones, parámetros, return, scope |
# | 04 | Listas y Diccionarios | Estructuras de datos, list comprehensions |
# | 05 | Archivos y Strings | Leer/escribir archivos, manipulación de texto |
#
# ### Bloque 2: Python Práctico (Notebooks 06–10)
#
# | # | Tema | Habilidad adquirida |
# |---|------|-------------------|
# | 06 | CSV y Excel | Leer datos tabulares, openpyxl, formatos |
# | 07 | Pandas | DataFrames, filtros, groupby, merge |
# | 08 | Matplotlib | Gráficas profesionales, subplots, estilos |
# | 09 | Web Scraping | BeautifulSoup, requests, extraer datos web |
# | 10 | APIs y JSON | Consumir APIs REST, parsear JSON |
#
# ### Bloque 3: Python + IA (Notebooks 11–15)
#
# | # | Tema | Habilidad adquirida |
# |---|------|-------------------|
# | 11 | NumPy | Arrays, operaciones vectorizadas, álgebra lineal |
# | 12 | Análisis Real | EDA completo con datos de Gapminder y World Bank |
# | 13 | Machine Learning | Scikit-learn, regresión, clasificación, evaluación |
# | 14 | Proyecto Final | APIs reales + ML + OpenAI GPT en un sistema integrado |
# | 15 | Próximos Pasos | Este notebook — tu mapa de ruta |

# %% [markdown]
# ---
#
# ## 2. Tu stack tecnológico
#
# Ahora manejas un stack completo de ciencia de datos:
#
# ```
# 🐍 Python
# ├── 📊 Pandas (análisis de datos)
# ├── 🔢 NumPy (cómputo numérico)
# ├── 📈 Matplotlib (visualización)
# ├── 🤖 Scikit-learn (machine learning)
# ├── 🌐 Requests (APIs y web)
# ├── 🍜 BeautifulSoup (web scraping)
# ├── 📄 openpyxl (Excel)
# └── 🧠 OpenAI (IA generativa)
# ```
#
# Este stack es el mismo que usan científicos de datos, analistas y desarrolladores de IA en empresas reales.

# %% [markdown]
# ---
#
# ## 3. Rutas de especialización
#
# Dependiendo de tus intereses, aquí tienes caminos recomendados:
#
# ### 🤖 Ruta: Inteligencia Artificial y Machine Learning
#
# Si te apasiona la IA, el siguiente paso es profundizar en ML y Deep Learning.
#
# | Paso | Tema | Recurso recomendado |
# |------|------|-------------------|
# | 1 | ML avanzado | Scikit-learn: pipelines, cross-validation, hyperparameter tuning |
# | 2 | Deep Learning | TensorFlow o PyTorch (redes neuronales) |
# | 3 | NLP | Hugging Face Transformers, LangChain |
# | 4 | Computer Vision | OpenCV, YOLO, CNNs |
# | 5 | MLOps | MLflow, Docker, despliegue de modelos |
#
# **Cursos recomendados:**
# - [fast.ai](https://www.fast.ai/) — Curso gratuito, práctico, excelente para empezar Deep Learning
# - [Hugging Face Course](https://huggingface.co/learn) — NLP y modelos de lenguaje
# - [Kaggle Learn](https://www.kaggle.com/learn) — Micro-cursos gratuitos y prácticos
#
# ### 📊 Ruta: Ciencia de Datos y Analytics
#
# Si te interesa analizar datos para tomar decisiones de negocio.
#
# | Paso | Tema | Recurso |
# |------|------|---------|
# | 1 | SQL | PostgreSQL, consultas avanzadas, joins |
# | 2 | Estadística | scipy.stats, pruebas de hipótesis, intervalos de confianza |
# | 3 | Visualización avanzada | Plotly, Seaborn, dashboards interactivos |
# | 4 | Big Data | PySpark, Google BigQuery |
# | 5 | BI Tools | Power BI, Tableau, Looker |
#
# **Cursos recomendados:**
# - [Mode Analytics SQL Tutorial](https://mode.com/sql-tutorial/) — SQL desde cero
# - [Kaggle Competitions](https://www.kaggle.com/competitions) — Practica con datos reales
#
# ### 🌐 Ruta: Desarrollo Web con Python
#
# Si quieres construir aplicaciones web.
#
# | Paso | Tema | Recurso |
# |------|------|---------|
# | 1 | Backend | FastAPI o Flask (APIs REST) |
# | 2 | Bases de datos | PostgreSQL, MongoDB, SQLAlchemy |
# | 3 | Frontend básico | HTML/CSS/JavaScript, React o Next.js |
# | 4 | Deploy | Railway, Vercel, AWS, Docker |
# | 5 | Full Stack AI | Streamlit, Gradio (interfaces de ML) |
#
# **Cursos recomendados:**
# - [FastAPI docs](https://fastapi.tiangolo.com/) — La mejor documentación para aprender APIs
# - [Streamlit](https://streamlit.io/) — Convierte scripts de Python en apps web en minutos
#
# ### 🏗️ Ruta: Automatización y Agentes de IA
#
# Si quieres crear sistemas que trabajen por ti.
#
# | Paso | Tema | Recurso |
# |------|------|---------|
# | 1 | APIs avanzadas | OAuth, webhooks, rate limiting |
# | 2 | Agentes de IA | LangChain, CrewAI, AutoGen |
# | 3 | Voice AI | LiveKit, OpenAI Realtime API, Deepgram |
# | 4 | Automatización | n8n, Make, Python scripts con cron |
# | 5 | MCP / Tool Use | Model Context Protocol, function calling |
#
# **Cursos recomendados:**
# - [LangChain docs](https://python.langchain.com/) — Framework para agentes de IA
# - [DeepLearning.AI Short Courses](https://www.deeplearning.ai/short-courses/) — Cursos cortos y prácticos

# %% [markdown]
# ---
#
# ## 4. Proyectos para practicar
#
# La mejor forma de aprender es construyendo. Aquí tienes ideas de proyectos ordenados por dificultad:
#
# ### 🟢 Principiante (usa lo de Notebooks 01–07)
#
# 1. **Gestor de gastos personal** — Registra ingresos/gastos en CSV, genera resumen mensual con gráficas
# 2. **Scraper de precios** — Monitorea precios de productos y alerta cuando bajan
# 3. **Generador de reportes** — Lee datos de Excel y genera PDFs con resumen ejecutivo
#
# ### 🟡 Intermedio (usa lo de Notebooks 08–13)
#
# 4. **Dashboard de ventas** — Conecta a datos reales de tu negocio, visualiza KPIs
# 5. **Predictor de demanda** — Usa ML para predecir ventas del próximo mes
# 6. **Chatbot de FAQ** — Usa OpenAI API para responder preguntas sobre tu empresa
#
# ### 🔴 Avanzado (usa todo + tecnologías nuevas)
#
# 7. **Agente de voz** — Asistente de ventas por teléfono con LiveKit + OpenAI
# 8. **Sistema de recomendación** — Recomienda productos basado en historial de compras
# 9. **Plataforma de BI** — Dashboard web con Streamlit que se actualiza en tiempo real

# %% [markdown]
# ---
#
# ## 5. Recursos de la comunidad

# %%
# Tu mapa de recursos interactivo
recursos = {
    "📚 Aprendizaje gratuito": {
        "Kaggle Learn": "https://www.kaggle.com/learn",
        "fast.ai": "https://www.fast.ai/",
        "freeCodeCamp": "https://www.freecodecamp.org/",
        "Google AI": "https://ai.google/education/",
        "DeepLearning.AI": "https://www.deeplearning.ai/short-courses/",
    },
    "🛠️ Herramientas": {
        "Google Colab": "https://colab.research.google.com/",
        "Kaggle Notebooks": "https://www.kaggle.com/code",
        "GitHub": "https://github.com/",
        "VS Code": "https://code.visualstudio.com/",
        "Streamlit": "https://streamlit.io/",
    },
    "📖 Documentación oficial": {
        "Python": "https://docs.python.org/3/",
        "Pandas": "https://pandas.pydata.org/docs/",
        "Scikit-learn": "https://scikit-learn.org/stable/",
        "Matplotlib": "https://matplotlib.org/stable/",
        "OpenAI API": "https://platform.openai.com/docs/",
    },
    "🌐 Comunidades": {
        "Culiacan.AI": "https://culiacan.ai",
        "Stack Overflow": "https://stackoverflow.com/",
        "Reddit r/learnpython": "https://reddit.com/r/learnpython",
        "Kaggle Forums": "https://www.kaggle.com/discussions",
        "Hugging Face": "https://huggingface.co/",
    },
}

for categoria, links in recursos.items():
    print(f"\n{categoria}")
    print("-" * 40)
    for nombre, url in links.items():
        print(f"  🔗 {nombre:<25} {url}")

# %% [markdown]
# ---
#
# ## 6. Tu checklist de habilidades
#
# Marca lo que ya dominas y lo que te falta practicar:

# %%
# Autoevaluación de habilidades
habilidades = {
    "🐍 Python básico": {
        "Variables y tipos de datos": True,
        "Condicionales y ciclos": True,
        "Funciones": True,
        "Listas y diccionarios": True,
        "Manejo de archivos": True,
    },
    "📊 Datos": {
        "Leer CSV y Excel": True,
        "Pandas (DataFrames, groupby, merge)": True,
        "NumPy (arrays, operaciones vectorizadas)": True,
        "Visualización con Matplotlib": True,
    },
    "🌐 Web y APIs": {
        "Requests (HTTP GET/POST)": True,
        "Parsear JSON": True,
        "Web scraping con BeautifulSoup": True,
        "Consumir APIs REST": True,
    },
    "🤖 IA y Machine Learning": {
        "Train/test split": True,
        "Regresión (predecir números)": True,
        "Clasificación (predecir categorías)": True,
        "Evaluar modelos (R², accuracy)": True,
        "OpenAI API (GPT)": True,
    },
    "🚀 Próximo nivel": {
        "SQL y bases de datos": False,
        "Deep Learning (TensorFlow/PyTorch)": False,
        "FastAPI (crear APIs propias)": False,
        "Docker y deploy": False,
        "Agentes de IA (LangChain)": False,
    },
}

total = 0
completadas = 0
print("📋 CHECKLIST DE HABILIDADES")
print("=" * 50)

for categoria, skills in habilidades.items():
    print(f"\n{categoria}")
    for skill, dominada in skills.items():
        total += 1
        if dominada:
            completadas += 1
        icono = "✅" if dominada else "⬜"
        print(f"  {icono} {skill}")

print(f"\n{'=' * 50}")
print(f"Progreso: {completadas}/{total} ({completadas/total*100:.0f}%)")
print(f"\n💡 Las habilidades de 'Próximo nivel' son tu siguiente meta.")
print(f"   ¡Ya tienes la base para aprenderlas!")

# %% [markdown]
# ---
#
# ## 7. Certificado de completado

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from datetime import datetime

fig, ax = plt.subplots(figsize=(14, 10))
fig.patch.set_facecolor("white")

# Borde dorado
borde = patches.FancyBboxPatch((0.02, 0.02), 0.96, 0.96, boxstyle="round,pad=0.02",
                                 linewidth=4, edgecolor="#D4AF37", facecolor="#FFFEF7")
ax.add_patch(borde)

# Borde interior
borde2 = patches.FancyBboxPatch((0.04, 0.04), 0.92, 0.92, boxstyle="round,pad=0.01",
                                  linewidth=1, edgecolor="#D4AF37", facecolor="none", linestyle="--")
ax.add_patch(borde2)

# Textos
ax.text(0.5, 0.88, "CERTIFICADO DE COMPLETADO", ha="center", va="center",
        fontsize=20, fontweight="bold", color="#333333", fontfamily="serif")

ax.text(0.5, 0.80, "— Culiacan.AI —", ha="center", va="center",
        fontsize=14, color="#D4AF37", fontfamily="serif")

ax.text(0.5, 0.68, "Se otorga el presente certificado a:", ha="center", va="center",
        fontsize=12, color="#666666", fontfamily="serif")

# Línea para el nombre
ax.plot([0.2, 0.8], [0.58, 0.58], color="#333333", linewidth=1)
ax.text(0.5, 0.60, "[Tu nombre aquí]", ha="center", va="center",
        fontsize=18, fontweight="bold", color="#2E86AB", fontfamily="serif", style="italic")

ax.text(0.5, 0.48, "Por haber completado exitosamente el curso", ha="center", va="center",
        fontsize=12, color="#666666", fontfamily="serif")

ax.text(0.5, 0.40, "Aprende Python con Google Colab", ha="center", va="center",
        fontsize=22, fontweight="bold", color="#2E86AB", fontfamily="serif")

ax.text(0.5, 0.32, "15 notebooks · Python · Pandas · NumPy · Matplotlib\n"
        "Scikit-learn · APIs · Web Scraping · OpenAI · Machine Learning",
        ha="center", va="center", fontsize=10, color="#888888", fontfamily="serif")

fecha = datetime.now().strftime("%d de %B de %Y")
meses_es = {"January": "enero", "February": "febrero", "March": "marzo", "April": "abril",
            "May": "mayo", "June": "junio", "July": "julio", "August": "agosto",
            "September": "septiembre", "October": "octubre", "November": "noviembre", "December": "diciembre"}
for en, es in meses_es.items():
    fecha = fecha.replace(en, es)

ax.text(0.5, 0.20, f"Culiacán, Sinaloa — {fecha}", ha="center", va="center",
        fontsize=11, color="#666666", fontfamily="serif")

ax.text(0.5, 0.10, "culiacan.ai", ha="center", va="center",
        fontsize=14, fontweight="bold", color="#D4AF37", fontfamily="serif")

ax.text(0.5, 0.06, "Culiacán reconocida en el mundo por su talento\ny emprendimiento en Inteligencia Artificial",
        ha="center", va="center", fontsize=8, color="#999999", fontfamily="serif")

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

plt.savefig("certificado_culiacanai.png", dpi=200, bbox_inches="tight", facecolor="white")
print("✅ Certificado guardado como certificado_culiacanai.png")
print("   Descárgalo y agrega tu nombre para compartirlo 🎉")
plt.show()

# %% [markdown]
# ---
#
# ## 8. Mensaje final
#
# > *"El mejor momento para aprender Python fue hace 5 años. El segundo mejor momento es hoy."*
#
# Ya diste el paso más importante: **empezar**. Ahora tienes las herramientas para:
#
# - **Automatizar** tareas repetitivas en tu trabajo
# - **Analizar datos** para tomar mejores decisiones
# - **Construir** aplicaciones inteligentes con IA
# - **Seguir aprendiendo** con una base sólida
#
# ### Conéctate con Culiacan.AI
#
# - 🌐 [culiacan.ai](https://culiacan.ai) — Plataforma y comunidad
# - 💻 [github.com/culiacanai](https://github.com/culiacanai) — Código abierto
# - 📱 Síguenos en redes sociales
#
# ### Comparte tu logro
#
# Si completaste el curso, compártelo:
# 1. Descarga tu certificado
# 2. Publica en LinkedIn o redes con el hashtag **#CuliacanAI**
# 3. Cuéntanos qué proyecto vas a construir
#
# ---
#
# <p align="center" style="font-size: 24px;">
#   🚀 El futuro es de quienes lo construyen con código 🚀
# </p>
#
# ---
#
# <p align="center">
#   Hecho con ❤️ por <a href="https://culiacan.ai">Culiacan.AI</a> — Culiacán reconocida en el mundo por su talento y emprendimiento en Inteligencia Artificial
# </p>
